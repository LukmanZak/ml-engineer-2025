# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import numpy as np

# %%
n_samples = 5000
data = {
        'provinsi_id': np.random.randint(1, 35, n_samples),  # 34 provinsi
        'kabupaten_id': np.random.randint(1, 515, n_samples),  # ~514 kab/kota
        'kepadatan_penduduk': np.random.lognormal(5, 1.5, n_samples),
        'tingkat_pendidikan': np.random.normal(8.5, 2.5, n_samples),  # rata2 tahun sekolah
        'tingkat_pengangguran': np.random.gamma(2, 3, n_samples),  # %
        'akses_air_bersih': np.random.beta(7, 2, n_samples) * 100,  # %
        'akses_listrik': np.random.beta(8, 1.5, n_samples) * 100,  # %
        'fasilitas_kesehatan': np.random.poisson(15, n_samples),  # per 10k penduduk
        'jalan_aspal': np.random.beta(5, 3, n_samples) * 100,  # %
        'luas_sawah': np.random.exponential(5000, n_samples),  # hektar
        'pendapatan_perkapita': np.random.lognormal(14.5, 0.8, n_samples),  # rupiah/bulan
        'jenis_wilayah': np.random.choice(['urban', 'rural'], n_samples, p=[0.6, 0.4])
    }

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       provinsi_id  kabupaten_id  kepadatan_penduduk  tingkat_pendidikan  \
# 0              27           380          275.993366            6.195379
# 1              16            84          113.498011           11.855878
# 2              27           411          306.020230            8.628373
# 3               7           221           41.560935            7.674385
# 4              16            78          103.633391            9.445138
# ...           ...           ...                 ...                 ...
# 4995           32           116          239.783711           11.221832
# 4996           16           156          644.652838           10.447609
# 4997           19           109           98.635075           10.793040
# 4998           14           330          117.584664           10.882580
# 4999           31           244           21.493681            7.273646
#
#       tingkat_pengangguran  akses_air_bersih  akses_listrik  \
# 0                12.731975         58.209852      68.085994
# 1                 2.730515         70.076751      61.047407
# 2                 5.077963         93.178346      83.270381
# 3                14.370874         80.675507      93.424962
# 4                 7.324625         93.532929      77.530889
# ...                    ...               ...            ...
# 4995              2.313656         82.490191      99.067337
# 4996              9.021351         83.821680      87.806195
# 4997              6.688788         89.109776      87.243733
# 4998             12.044552         54.383087      76.643606
# 4999              1.358224         69.423725      80.443204
#
#       fasilitas_kesehatan  jalan_aspal    luas_sawah  pendapatan_perkapita  \
# 0                      11    67.566386  18600.020621          1.825657e+06
# 1                      18    67.486958   2723.657763          1.519617e+06
# 2                      20    58.413336   2758.631273          3.729450e+06
# 3                      18    74.057577   9732.912606          1.542648e+06
# 4                      14    55.556559   6065.250459          2.729549e+06
# ...                   ...          ...           ...                   ...
# 4995                   16    78.154494   2051.844637          2.083741e+06
# 4996                   18    69.114678   4923.503051          1.982096e+06
# 4997                    8    54.806571   4185.865302          3.810731e+06
# 4998                   15    66.339085  13840.997466          5.837477e+05
# 4999                   24    72.286742   1353.434032          2.199902e+06
#
#      jenis_wilayah
# 0            rural
# 1            rural
# 2            rural
# 3            urban
# 4            rural
# ...            ...
# 4995         rural
# 4996         urban
# 4997         urban
# 4998         rural
# 4999         urban
#
# [5000 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   provinsi_id           5000 non-null   int32
#  1   kabupaten_id          5000 non-null   int32
#  2   kepadatan_penduduk    5000 non-null   float64
#  3   tingkat_pendidikan    5000 non-null   float64
#  4   tingkat_pengangguran  5000 non-null   float64
#  5   akses_air_bersih      5000 non-null   float64
#  6   akses_listrik         5000 non-null   float64
#  7   fasilitas_kesehatan   5000 non-null   int32
#  8   jalan_aspal           5000 non-null   float64
#  9   luas_sawah            5000 non-null   float64
#  10  pendapatan_perkapita  5000 non-null   float64
#  11  jenis_wilayah         5000 non-null   object
# dtypes: float64(8), int32(3), object(1)
# memory usage: 410.3+ KB

# %%
pendapatan = df['pendapatan_perkapita']<1800000
air = df['akses_air_bersih']<80
listrik = df['akses_listrik'] <85
pendidikan = df['tingkat_pendidikan']<8

# %%
df['kemiskinan'] = (pendapatan.astype(int) & (air.astype(int) + listrik.astype(int)+pendidikan.astype(int)>=2)).astype(int)

# %%
df
# Out:
#       provinsi_id  kabupaten_id  kepadatan_penduduk  tingkat_pendidikan  \
# 0              27           380          275.993366            6.195379
# 1              16            84          113.498011           11.855878
# 2              27           411          306.020230            8.628373
# 3               7           221           41.560935            7.674385
# 4              16            78          103.633391            9.445138
# ...           ...           ...                 ...                 ...
# 4995           32           116          239.783711           11.221832
# 4996           16           156          644.652838           10.447609
# 4997           19           109           98.635075           10.793040
# 4998           14           330          117.584664           10.882580
# 4999           31           244           21.493681            7.273646
#
#       tingkat_pengangguran  akses_air_bersih  akses_listrik  \
# 0                12.731975         58.209852      68.085994
# 1                 2.730515         70.076751      61.047407
# 2                 5.077963         93.178346      83.270381
# 3                14.370874         80.675507      93.424962
# 4                 7.324625         93.532929      77.530889
# ...                    ...               ...            ...
# 4995              2.313656         82.490191      99.067337
# 4996              9.021351         83.821680      87.806195
# 4997              6.688788         89.109776      87.243733
# 4998             12.044552         54.383087      76.643606
# 4999              1.358224         69.423725      80.443204
#
#       fasilitas_kesehatan  jalan_aspal    luas_sawah  pendapatan_perkapita  \
# 0                      11    67.566386  18600.020621          1.825657e+06
# 1                      18    67.486958   2723.657763          1.519617e+06
# 2                      20    58.413336   2758.631273          3.729450e+06
# 3                      18    74.057577   9732.912606          1.542648e+06
# 4                      14    55.556559   6065.250459          2.729549e+06
# ...                   ...          ...           ...                   ...
# 4995                   16    78.154494   2051.844637          2.083741e+06
# 4996                   18    69.114678   4923.503051          1.982096e+06
# 4997                    8    54.806571   4185.865302          3.810731e+06
# 4998                   15    66.339085  13840.997466          5.837477e+05
# 4999                   24    72.286742   1353.434032          2.199902e+06
#
#      jenis_wilayah  kemiskinan
# 0            rural           0
# 1            rural           1
# 2            rural           0
# 3            urban           0
# 4            rural           0
# ...            ...         ...
# 4995         rural           0
# 4996         urban           0
# 4997         urban           0
# 4998         rural           1
# 4999         urban           0
#
# [5000 rows x 13 columns]

# %%
numeric_cols = ['kepadatan_penduduk','tingkat_pendidikan',
                'tingkat_pengangguran','akses_air_bersih','akses_listrik',
                'fasilitas_kesehatan','jalan_aspal',
                'luas_sawah','pendapatan_perkapita']
cat_cols = ['jenis_wilayah']

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numeric_cols),
        ('cat', OneHotEncoder(), cat_cols)])

# %%
X = df[numeric_cols + cat_cols]

# %%
from sklearn.pipeline import Pipeline
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])
X = df[numeric_cols + cat_cols]
X_processed = pipeline.fit_transform(X)

# %%
y = df['kemiskinan']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_processed, y, test_size=0.2, random_state=42
)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
model = keras.Sequential([
    keras.layers.Input(shape=(X_train.shape[1],)),
    keras.layers.Dense(16, activation="relu"),
    keras.layers.Dense(8, activation="relu"),
    keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = keras.callbacks.EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=50,
    batch_size=32,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5593 - loss: 0.7049 - val_accuracy: 0.8180 - val_loss: 0.4719
# Epoch 2/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8147 - loss: 0.4470 - val_accuracy: 0.8210 - val_loss: 0.3700
# Epoch 3/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8276 - loss: 0.3572 - val_accuracy: 0.8470 - val_loss: 0.3164
# Epoch 4/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8564 - loss: 0.3007 - val_accuracy: 0.8710 - val_loss: 0.2831
# Epoch 5/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8748 - loss: 0.2809 - val_accuracy: 0.8810 - val_loss: 0.2565
# Epoch 6/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8971 - loss: 0.2437 - val_accuracy: 0.8920 - val_loss: 0.2351
# Epoch 7/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9049 - loss: 0.2286 - val_accuracy: 0.8970 - val_loss: 0.2207
# Epoch 8/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9035 - loss: 0.2230 - val_accuracy: 0.8980 - val_loss: 0.2117
# Epoch 9/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9156 - loss: 0.2031 - val_accuracy: 0.9050 - val_loss: 0.2048
# Epoch 10/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9173 - loss: 0.1970 - val_accuracy: 0.9070 - val_loss: 0.1993
# Epoch 11/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9099 - loss: 0.1964 - val_accuracy: 0.9060 - val_loss: 0.1979
# Epoch 12/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9209 - loss: 0.1850 - val_accuracy: 0.9030 - val_loss: 0.1936
# Epoch 13/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9191 - loss: 0.1843 - val_accuracy: 0.9090 - val_loss: 0.1937
# Epoch 14/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.1912 - val_accuracy: 0.9090 - val_loss: 0.1925
# Epoch 15/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9140 - loss: 0.1839 - val_accuracy: 0.9100 - val_loss: 0.1891
# Epoch 16/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9297 - loss: 0.1733 - val_accuracy: 0.9080 - val_loss: 0.1884
# Epoch 17/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9268 - loss: 0.1745 - val_accuracy: 0.9090 - val_loss: 0.1881
# Epoch 18/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9311 - loss: 0.1731 - val_accuracy: 0.9160 - val_loss: 0.1853
# Epoch 19/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9313 - loss: 0.1562 - val_accuracy: 0.9160 - val_loss: 0.1844
# Epoch 20/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9201 - loss: 0.1796 - val_accuracy: 0.9120 - val_loss: 0.1855
# Epoch 21/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9220 - loss: 0.1779 - val_accuracy: 0.9150 - val_loss: 0.1834
# Epoch 22/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9287 - loss: 0.1668 - val_accuracy: 0.9180 - val_loss: 0.1820
# Epoch 23/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9310 - loss: 0.1601 - val_accuracy: 0.9170 - val_loss: 0.1813
# Epoch 24/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9325 - loss: 0.1600 - val_accuracy: 0.9170 - val_loss: 0.1795
# Epoch 25/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9343 - loss: 0.1616 - val_accuracy: 0.9200 - val_loss: 0.1787
# Epoch 26/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9324 - loss: 0.1568 - val_accuracy: 0.9210 - val_loss: 0.1775
# Epoch 27/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9367 - loss: 0.1489 - val_accuracy: 0.9230 - val_loss: 0.1789
# Epoch 28/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9263 - loss: 0.1689 - val_accuracy: 0.9200 - val_loss: 0.1771
# Epoch 29/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9302 - loss: 0.1627 - val_accuracy: 0.9230 - val_loss: 0.1766
# Epoch 30/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9247 - loss: 0.1655 - val_accuracy: 0.9210 - val_loss: 0.1737
# Epoch 31/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9410 - loss: 0.1487 - val_accuracy: 0.9250 - val_loss: 0.1723
# Epoch 32/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9315 - loss: 0.1580 - val_accuracy: 0.9250 - val_loss: 0.1720
# Epoch 33/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9346 - loss: 0.1564 - val_accuracy: 0.9270 - val_loss: 0.1701
# Epoch 34/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9405 - loss: 0.1396 - val_accuracy: 0.9220 - val_loss: 0.1690
# Epoch 35/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9394 - loss: 0.1411 - val_accuracy: 0.9260 - val_loss: 0.1732
# Epoch 36/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9431 - loss: 0.1380 - val_accuracy: 0.9280 - val_loss: 0.1662
# Epoch 37/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9447 - loss: 0.1385 - val_accuracy: 0.9280 - val_loss: 0.1658
# Epoch 38/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9370 - loss: 0.1503 - val_accuracy: 0.9280 - val_loss: 0.1662
# Epoch 39/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9416 - loss: 0.1437 - val_accuracy: 0.9330 - val_loss: 0.1639
# Epoch 40/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9353 - loss: 0.1451 - val_accuracy: 0.9330 - val_loss: 0.1645
# Epoch 41/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9477 - loss: 0.1288 - val_accuracy: 0.9280 - val_loss: 0.1628
# Epoch 42/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9464 - loss: 0.1341 - val_accuracy: 0.9270 - val_loss: 0.1633
# Epoch 43/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9429 - loss: 0.1384 - val_accuracy: 0.9320 - val_loss: 0.1593
# Epoch 44/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9433 - loss: 0.1321 - val_accuracy: 0.9350 - val_loss: 0.1603
# Epoch 45/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9457 - loss: 0.1241 - val_accuracy: 0.9330 - val_loss: 0.1589
# Epoch 46/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9454 - loss: 0.1326 - val_accuracy: 0.9330 - val_loss: 0.1569
# Epoch 47/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9459 - loss: 0.1276 - val_accuracy: 0.9340 - val_loss: 0.1579
# Epoch 48/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9517 - loss: 0.1206 - val_accuracy: 0.9250 - val_loss: 0.1579
# Epoch 49/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9464 - loss: 0.1225 - val_accuracy: 0.9320 - val_loss: 0.1546
# Epoch 50/50
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9442 - loss: 0.1317 - val_accuracy: 0.9340 - val_loss: 0.1543

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report
y_pred_prob = model.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
cm = confusion_matrix(y_test, y_pred)

print("Accuracy:", acc)
print("Precision:", prec)
print("Recall:", rec)
print("Confusion Matrix:\n", cm)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Accuracy: 0.934
# Precision: 0.8372093023255814
# Recall: 0.7912087912087912
# Confusion Matrix:
#  [[790  28]
#  [ 38 144]]

# %%
import joblib
joblib.dump(preprocessor, "preprocessor.pkl")
joblib.dump(preprocessor, "BPS.pkl")
# Out:
# ['BPS.pkl']
